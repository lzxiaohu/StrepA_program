# %%
from line_profiler import LineProfiler
import numpy as np
import matplotlib.pyplot as plt
import functions_list
import os
import time

# %%
np.random.seed(40233)

DurationSimulation = 20  #duration of simulation by year
Nstrains = 42  #number of strains 42
Nagents = 2500  #total number of hosts
AgeDeath = 71  #age that all hosts die (years)
BasicReproductionNumber = 2.07
Dimmunity = 0.5 * 52.14  #duration of immunity (weeks)
x = 10  #resistance to co-infection
alpha = 3  #migration rate per week per population
Cperweek = 34.53  #number of contacts per week 34.53
sigma = 1  #strength of strain-specific immunity
omega = 0.1  #strength of cross-strain immunity

params = np.array([DurationSimulation, Nstrains, Dimmunity, sigma, omega, x,
                   Cperweek, Nagents, alpha, AgeDeath, BasicReproductionNumber], dtype=float)
print(params)
# Out:
# [2.000e+01 4.200e+01 2.607e+01 1.000e+00 1.000e-01 1.000e+01 3.453e+01
#  2.500e+03 3.000e+00 7.100e+01 2.070e+00]

# %%
[AgentCharacteristics, ImmuneStatus, _] = functions_list.initialise_agents(params)

# %%
lp = LineProfiler() 
lp_wrapper = lp(functions_list.simulator)

start = time.perf_counter()

[SSPrev,AgentsInfectedByKStrains] = lp_wrapper(AgentCharacteristics, ImmuneStatus, params, 0, 1)

end = time.perf_counter()

print(f"Elapsed: {end - start:.4f} s")
lp.print_stats
# Out:
# Elapsed: 332.7622 s
# <bound method LineProfiler.print_stats of <line_profiler.line_profiler.LineProfiler object at 0x166818460>>

# %%
lp = LineProfiler() 
lp_wrapper = lp(functions_list.simulator_v2)

start = time.perf_counter()

[SSPrev,AgentsInfectedByKStrains] = lp_wrapper(AgentCharacteristics, ImmuneStatus, params, 0, 1)

end = time.perf_counter()

print(f"Elapsed: {end - start:.4f} s")
lp.print_stats()
# Out:
# Elapsed: 202.9698 s
# Timer unit: 1e-09 s
#
# Total time: 187.122 s
# File: /Users/hcao/Library/CloudStorage/OneDrive-Personal/Research_Knowledge/Projects/StrepA/StrepA_program/code/functions_list.py
# Function: simulator_v2 at line 458
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    458                                           def simulator_v2(AgentCharacteristics, ImmuneStatus, params,
#    459                                                         specifyPtransmission: int = 0,
#    460                                                         cross_immunity_effect_on_coinfections: int = 1):
#    461                                               """
#    462                                               Python port of MATLAB simulator.m (optimised based on profiling)
#    463
#    464                                               Inputs
#    465                                               ------
#    466                                               AgentCharacteristics : (Nagents, Nstrains+1) float
#    467                                                   cols 0..Nstrains-1: infection copies per strain
#    468                                                   last col: agent age (years)
#    469                                               ImmuneStatus : (Nagents, Nstrains) int {0,1}
#    470                                               params : same container you pass to parameters(params)
#    471                                               specifyPtransmission : 1 to force Ptransmission=0.0301, else 0
#    472                                               cross_immunity_effect_on_coinfections : 1 on, 0 off
#    473
#    474                                               Returns
#    475                                               -------
#    476                                               SSPrev : (Nstrains, Ntimesteps)
#    477                                               AgentsInfectedByKStrains : (Nstrains, Ntimesteps)
#    478                                               """
#    479
#    480         1          0.0      0.0      0.0      (Nagents, Nstrains, Nst, AgeDeath, _NI0, _NR0,
#    481         1          0.0      0.0      0.0       Cpertimestep, MRpertimestep, Precovery, Pimmunityloss,
#    482         1          0.0      0.0      0.0       Ptransmission, x, StrengthImmunity, Immunity,
#    483         1          0.0      0.0      0.0       StrengthCrossImmunity, prevalence_in_migrants, CCC,
#    484         2     214000.0 107000.0      0.0       time, Ntimesteps, dt_years) = parameters(params)
#    485
#    486         1          0.0      0.0      0.0      Nagents   = int(Nagents)
#    487         1       1000.0   1000.0      0.0      Nstrains  = int(Nstrains)
#    488         1          0.0      0.0      0.0      Nst       = int(Nst)
#    489         1          0.0      0.0      0.0      AgeDeath  = float(AgeDeath)
#    490         1       1000.0   1000.0      0.0      CCC       = float(CCC)
#    491
#    492                                               # Optionally override Ptransmission
#    493         1          0.0      0.0      0.0      if specifyPtransmission == 1:
#    494                                                   Ptransmission = 0.0301
#    495
#    496                                               # ---- Cross-immunity-accelerated recovery probability per step ----
#    497         1       1000.0   1000.0      0.0      dt_weeks = 1.0/7.0  # from parameters.m
#    498         1       4000.0   4000.0      0.0      Rrecovery = -np.log(1.0 - Precovery) / dt_weeks
#    499         1       1000.0   1000.0      0.0      if StrengthCrossImmunity != 1:
#    500         1       1000.0   1000.0      0.0          Rrecovery_cici = 1.0 / ((1.0 / Rrecovery) * (1.0 - StrengthCrossImmunity))
#    501         1       1000.0   1000.0      0.0          Precovery_cici = 1.0 - np.exp(-dt_weeks * Rrecovery_cici)
#    502                                               else:
#    503                                                   Precovery_cici = 1.0
#    504
#    505                                               # ---- Pre-generated random streams (mirrors pregenerate_random_numbers.m) ----
#    506         1   46362000.0 4.64e+07      0.0      ContactRand = np.random.poisson(Cpertimestep, size=(1_000_000, 1)).astype(int)
#    507         1   17335000.0 1.73e+07      0.0      MRRand      = np.random.poisson(MRpertimestep, size=(1_000_000, 1)).astype(int)
#    508         1    2958000.0 2.96e+06      0.0      SamplingU   = np.random.rand(1_000_000, 1)
#    509         1       1000.0   1000.0      0.0      countCR = 0  # contacts
#    510         1          0.0      0.0      0.0      countMR = 0  # migrants
#    511         1       1000.0   1000.0      0.0      countU  = 0  # generic uniforms
#    512
#    513         1       2000.0   2000.0      0.0      def _takeU(n):
#    514                                                   nonlocal SamplingU, countU
#    515                                                   end = countU + n
#    516                                                   if end > len(SamplingU):
#    517                                                       SamplingU = np.random.rand(1_000_000, 1)
#    518                                                       countU = 0
#    519                                                       end = n
#    520                                                   out = SamplingU[countU:end, 0]
#    521                                                   countU = end
#    522                                                   return out
#    523
#    524         1          0.0      0.0      0.0      def _takeCR():
#    525                                                   nonlocal ContactRand, countCR
#    526                                                   x = ContactRand[countCR, 0]
#    527                                                   countCR += 1
#    528                                                   if countCR >= len(ContactRand):
#    529                                                       ContactRand = np.random.poisson(Cpertimestep, size=(1_000_000, 1)).astype(int)
#    530                                                       countCR = 0
#    531                                                   return x
#    532
#    533         1          0.0      0.0      0.0      def _takeMR():
#    534                                                   nonlocal MRRand, countMR
#    535                                                   x = MRRand[countMR, 0]
#    536                                                   countMR += 1
#    537                                                   if countMR >= len(MRRand):
#    538                                                       MRRand = np.random.poisson(MRpertimestep, size=(1_000_000, 1)).astype(int)
#    539                                                       countMR = 0
#    540                                                   return x
#    541
#    542                                               # ---- Outputs ----
#    543         1     169000.0 169000.0      0.0      SSPrev = np.zeros((Nstrains, Ntimesteps), dtype=float)
#    544         1     151000.0 151000.0      0.0      AgentsInfectedByKStrains = np.zeros((Nstrains, Ntimesteps), dtype=float)
#    545
#    546                                               # t = 0
#    547         1       3000.0   3000.0      0.0      BB = AgentCharacteristics[:, :Nstrains]
#    548         1     179000.0 179000.0      0.0      SSPrev[:, 0] = BB.sum(axis=0)
#    549
#    550         1      43000.0  43000.0      0.0      tot0 = BB.sum()
#    551         1       2000.0   2000.0      0.0      if tot0 > 1:
#    552         1      46000.0  46000.0      0.0          kvec = BB.sum(axis=1).astype(int)
#    553         1      21000.0  21000.0      0.0          kvec = kvec[kvec != 0]
#    554         1          0.0      0.0      0.0          if kvec.size:
#    555         1      71000.0  71000.0      0.0              K, counts = np.unique(kvec, return_counts=True)
#    556         1       8000.0   8000.0      0.0              AgentsInfectedByKStrains[K - 1, 0] = counts
#    557                                               elif tot0 == 1:
#    558                                                   AgentsInfectedByKStrains[0, 0] = 1
#    559
#    560                                               # Tracks “fast recovery” flags (CICI) for each (agent, strain)
#    561         1      83000.0  83000.0      0.0      CICI = np.zeros_like(BB)
#    562
#    563                                               # ---- Main time loop ----
#    564      7300    1790000.0    245.2      0.0      for t in range(Ntimesteps - 1):
#    565      7299  118036000.0  16171.5      0.1          CurrentAC  = AgentCharacteristics.copy()
#    566      7299  188186000.0  25782.4      0.1          CurrentImm = ImmuneStatus.copy()
#    567      7299   66567000.0   9120.0      0.0          DD = CurrentAC[:, :Nst]  # infections per strain at start of step
#    568
#    569                                                   # ===== RECOVERY =====
#    570      7299  731712000.0 100248.3      0.4          inf_norm = (DD > 0) & (CICI == 0)
#    571      7299  667166000.0  91405.1      0.4          inf_cici = (DD > 0) & (CICI > 0)
#    572
#    573      7299 1605720000.0 219991.8      0.9          r_n_rows, r_n_cols = np.where(inf_norm)
#    574      7299    1707000.0    233.9      0.0          if r_n_rows.size:
#    575      7299   33082000.0   4532.4      0.0              rec = (np.random.rand(r_n_rows.size) < Precovery)
#    576      7299   26366000.0   3612.3      0.0              AgentCharacteristics[r_n_rows[rec], r_n_cols[rec]] = 0
#    577                                                       # only normal recoveries gain ss-immunity
#    578      7299   18083000.0   2477.5      0.0              ImmuneStatus[r_n_rows[rec], r_n_cols[rec]] = 1 * Immunity
#    579
#    580      7299 1606846000.0 220146.0      0.9          r_c_rows, r_c_cols = np.where(inf_cici)
#    581      7299    1558000.0    213.5      0.0          if r_c_rows.size:
#    582      7298   20549000.0   2815.7      0.0              rec = (np.random.rand(r_c_rows.size) < Precovery_cici)
#    583      7298   18038000.0   2471.6      0.0              AgentCharacteristics[r_c_rows[rec], r_c_cols[rec]] = 0
#    584      7298   12502000.0   1713.1      0.0              CICI[r_c_rows[rec], r_c_cols[rec]] = 0  # no immunity granted here
#    585
#    586                                                   # ===== WANING IMMUNITY =====
#    587      7299 2303574000.0 315601.3      1.2          w_rows, w_cols = np.where(CurrentImm == 1)
#    588      7299    1626000.0    222.8      0.0          if w_rows.size:
#    589      7299  228640000.0  31324.8      0.1              lose = (np.random.rand(w_rows.size) < Pimmunityloss)
#    590      7299   44760000.0   6132.3      0.0              ImmuneStatus[w_rows[lose], w_cols[lose]] = 0
#    591
#    592                                                   # ===== TRANSMISSION =====
#    593                                                   # Reuse TotalInf for both G and susceptibility calculation
#    594      7299  240295000.0  32921.6      0.1          TotalInf = DD.sum(axis=1)
#    595      7299   32846000.0   4500.1      0.0          infected_agents = np.where(TotalInf > 0)[0]
#    596
#    597      7299    1869000.0    256.1      0.0          if infected_agents.size:
#    598                                                       # base per-contact susceptibility, with co-infection resistance
#    599      7299  140161000.0  19202.8      0.1              P1 = Ptransmission * np.power((1.0 - TotalInf / CCC), x)
#    600      7299  107400000.0  14714.3      0.1              P1 = np.clip(P1, 0.0, 1.0)
#    601
#    602                                                       # expand to (Nagents, Nstrains)
#    603      7299 1562326000.0 214046.6      0.8              InfectionProb = np.repeat(P1[:, None], Nstrains, axis=1)
#    604
#    605                                                       # strain-specific immunity
#    606      7299    1852000.0    253.7      0.0              if StrengthImmunity > 0:
#    607      7299   92106000.0  12619.0      0.0                  mask_ss = (CurrentImm == 1)
#    608      7299 2237071000.0 306490.1      1.2                  InfectionProb[mask_ss] *= (1.0 - StrengthImmunity)
#    609
#    610                                                       # cross-strain immunity (any immunity to any strain)
#    611      7299    2102000.0    288.0      0.0              if StrengthCrossImmunity > 0:
#    612      7299  207416000.0  28417.0      0.1                  any_imm = (CurrentImm == 1).any(axis=1)[:, None]
#    613      7299 1410220000.0 193207.3      0.8                  mask_cs = (CurrentImm == 0) & np.repeat(any_imm, Nstrains, axis=1)
#    614      7299 2475594000.0 339168.9      1.3                  InfectionProb[mask_cs] *= (1.0 - StrengthCrossImmunity)
#    615
#    616   8783271 2015665000.0    229.5      1.1              for a in infected_agents:
#    617   8775972     2.13e+10   2425.7     11.4                  infecting_strains = np.where(DD[a, :] > 0)[0]
#    618   8775972 1978620000.0    225.5      1.1                  if infecting_strains.size == 0:
#    619                                                               continue
#    620
#    621   8775972 7436630000.0    847.4      4.0                  X = _takeCR()  # contacts for this source agent
#    622   8775972 1829750000.0    208.5      1.0                  if X <= 0:
#    623     62982   11093000.0    176.1      0.0                      continue
#    624
#    625                                                           # sample contacts (with replacement), avoid self efficiently
#    626   8712990 8365924000.0    960.2      4.5                  U = _takeU(X)
#    627                                                           # map U into 0..Nagents-2 and then "skip" a
#    628   8712990     1.03e+10   1178.4      5.5                  contacts = (U * (Nagents - 1)).astype(int)
#    629   8712990     1.45e+10   1669.7      7.8                  contacts[contacts >= a] += 1  # now in 0..Nagents-1, excluding a
#    630
#    631                                                           # choose one transmitting strain per contact among agent's strains
#    632   8712990 8716328000.0   1000.4      4.7                  U2 = _takeU(X)
#    633   8712990 1941634000.0    222.8      1.0                  if infecting_strains.size == 1:
#    634   6774982 2555494000.0    377.2      1.4                      chosen = np.empty(X, dtype=int)
#    635   6774982 2594012000.0    382.9      1.4                      chosen.fill(infecting_strains[0])
#    636                                                           else:
#    637   1938008 2255270000.0   1163.7      1.2                      idx = (U2 * infecting_strains.size).astype(int)
#    638   1938008 1819649000.0    938.9      1.0                      idx[idx == infecting_strains.size] = infecting_strains.size - 1
#    639   1938008  630086000.0    325.1      0.3                      chosen = infecting_strains[idx]
#    640
#    641                                                           # success Bernoulli
#    642   8712990 7267698000.0    834.1      3.9                  susc = InfectionProb[contacts, chosen]
#    643   8712990 8597812000.0    986.8      4.6                  U3 = _takeU(X)
#    644   8712990 4363989000.0    500.9      2.3                  success = (U3 < susc)
#    645
#    646   8712990     3.36e+10   3857.8     18.0                  if np.any(success):
#    647    769103  412242000.0    536.0      0.2                      contacts = contacts[success]
#    648    769103  345877000.0    449.7      0.2                      chosen   = chosen[success]
#    649                                                               # dedupe same contact (keep first)
#    650    769103 1828630000.0   2377.6      1.0                      order = np.argsort(contacts)
#    651    769103  253627000.0    329.8      0.1                      contacts = contacts[order]
#    652    769103  227309000.0    295.6      0.1                      chosen   = chosen[order]
#    653    769103 5891388000.0   7660.1      3.1                      keep = np.concatenate([[True], np.diff(contacts) > 0])
#    654    769103  393963000.0    512.2      0.2                      contacts = contacts[keep]
#    655    769103  328138000.0    426.7      0.2                      chosen   = chosen[keep]
#    656
#    657                                                               # increment copies from the snapshot state
#    658    769103 1715276000.0   2230.2      0.9                      AgentCharacteristics[contacts, chosen] = CurrentAC[contacts, chosen] + 1
#    659
#    660    769103  204084000.0    265.4      0.1                      if cross_immunity_effect_on_coinfections == 1:
#    661                                                                   # --- Optimised cross-immunity update: only touched rows ---
#    662    769103  953796000.0   1240.1      0.5                          temp = AgentCharacteristics[contacts, :Nstrains].copy()
#    663    769103  940440000.0   1222.8      0.5                          temp[np.arange(contacts.size), chosen] = 0   # remove newly acquired strain
#    664    769103  979134000.0   1273.1      0.5                          temp[temp > 0] = 1                           # mark other extant strains
#    665   1538206      1.1e+10   7124.2      5.9                          CICI[contacts, :] = np.clip(
#    666    769103  929204000.0   1208.2      0.5                              CICI[contacts, :] + temp,
#    667    769103  167550000.0    217.9      0.1                              0,
#    668    769103  151733000.0    197.3      0.1                              1,
#    669                                                                   )
#    670
#    671                                                               # those contacts cannot be infected again in this pass
#    672    769103  749893000.0    975.0      0.4                      InfectionProb[contacts, :] = 0.0
#    673
#    674                                                   # ===== AGE, DEATH, BIRTH =====
#    675      7299   58803000.0   8056.3      0.0          AgentCharacteristics[:, Nstrains] = dt_years + CurrentAC[:, Nstrains]
#    676      7299   33159000.0   4543.0      0.0          dead = np.where(AgentCharacteristics[:, Nstrains] > AgeDeath)[0]
#    677      7299    2050000.0    280.9      0.0          if dead.size:
#    678       689     900000.0   1306.2      0.0              AgentCharacteristics[dead, :Nstrains] = 0
#    679       689     723000.0   1049.3      0.0              ImmuneStatus[dead, :] = 0
#    680       689     851000.0   1235.1      0.0              AgentCharacteristics[dead, Nstrains] = 0.001
#    681       689     660000.0    957.9      0.0              CICI[dead, :] = 0
#    682
#    683                                                   # ===== MIGRATION =====
#    684      7299    7154000.0    980.1      0.0          NumMig = _takeMR()
#    685      7299    2099000.0    287.6      0.0          if NumMig > 0:
#    686      2528     759000.0    300.2      0.0              if NumMig >= Nagents:
#    687                                                           migrants = np.random.permutation(Nagents)
#    688                                                       else:
#    689      2528   79178000.0  31320.4      0.0                  migrants = np.random.choice(Nagents, size=NumMig, replace=False)
#    690
#    691      2528    4545000.0   1797.9      0.0              infected_mig = (np.random.rand(NumMig) < prevalence_in_migrants)
#    692      2528    5474000.0   2165.3      0.0              n_im = int(infected_mig.sum())
#    693      2528     733000.0    290.0      0.0              if n_im > 0:
#    694       315    3320000.0  10539.7      0.0                  mig_strains = np.random.randint(0, Nst, size=n_im)  # 0..Nst-1
#    695
#    696      2528     745000.0    294.7      0.0              cm = ci = 0
#    697      5612    2115000.0    376.9      0.0              for m in range(NumMig):
#    698      3084    1179000.0    382.3      0.0                  idx = migrants[m]
#    699      3084    2095000.0    679.3      0.0                  ImmuneStatus[idx, :] = 0
#    700      3084    1779000.0    576.8      0.0                  CICI[idx, :] = 0
#    701      3084    2534000.0    821.7      0.0                  AgentCharacteristics[idx, Nstrains] = np.random.rand() * AgeDeath
#    702      3084    1676000.0    543.5      0.0                  AgentCharacteristics[idx, :Nstrains] = 0
#    703      3084     926000.0    300.3      0.0                  if infected_mig[cm]:
#    704       321     163000.0    507.8      0.0                      AgentCharacteristics[idx, mig_strains[ci]] = 1
#    705       321      93000.0    289.7      0.0                      ci += 1
#    706      3084     903000.0    292.8      0.0                  cm += 1
#    707
#    708                                                   # ===== RECORDING =====
#    709      7299    3370000.0    461.7      0.0          BB = AgentCharacteristics[:, :Nstrains]
#    710      7299  311191000.0  42634.7      0.2          SSPrev[:, t + 1] = BB.sum(axis=0)
#    711
#    712      7299  252153000.0  34546.2      0.1          tot = BB.sum()
#    713      7299    2512000.0    344.2      0.0          if tot > 1:
#    714      7299  242169000.0  33178.4      0.1              kvec = BB.sum(axis=1).astype(int)
#    715      7299   86185000.0  11807.8      0.0              kvec = kvec[kvec != 0]
#    716      7299    2198000.0    301.1      0.0              if kvec.size:
#    717      7299  191344000.0  26215.1      0.1                  K, counts = np.unique(kvec, return_counts=True)
#    718      7299   14628000.0   2004.1      0.0                  AgentsInfectedByKStrains[K - 1, t + 1] = counts
#    719                                                   elif tot == 1:
#    720                                                       AgentsInfectedByKStrains[0, t + 1] = 1
#    721
#    722         1          0.0      0.0      0.0      return SSPrev, AgentsInfectedByKStrains

# %%
lp.print_stats()
# Out:
# Timer unit: 1e-09 s
#
# Total time: 316.153 s
# File: /Users/hcao/Library/CloudStorage/OneDrive-Personal/Research_Knowledge/Projects/StrepA/StrepA_program/code/functions_list.py
# Function: simulator at line 197
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    197                                           def simulator(AgentCharacteristics, ImmuneStatus, params,
#    198                                                         specifyPtransmission: int = 0,
#    199                                                         cross_immunity_effect_on_coinfections: int = 1):
#    200                                               """
#    201                                               Python port of MATLAB simulator.m
#    202
#    203                                               Inputs
#    204                                               ------
#    205                                               AgentCharacteristics : (Nagents, Nstrains+1) float
#    206                                                   cols 0..Nstrains-1: infection copies per strain
#    207                                                   last col: agent age (years)
#    208                                               ImmuneStatus : (Nagents, Nstrains) int {0,1}
#    209                                               params : same container you pass to parameters(params)
#    210                                               specify Ptransmission : 1 to force Ptransmission=0.0301, else 0
#    211                                               cross_immunity_effect_on_coinfections : 1 on, 0 off
#    212
#    213                                               Returns
#    214                                               -------
#    215                                               SSPrev : (Nstrains, Ntimesteps)
#    216                                               AgentsInfectedByKStrains : (Nstrains, Ntimesteps)
#    217                                               """
#    218
#    219         1       2000.0   2000.0      0.0      (Nagents, Nstrains, Nst, AgeDeath, _NI0, _NR0,
#    220         1       1000.0   1000.0      0.0       Cpertimestep, MRpertimestep, Precovery, Pimmunityloss,
#    221         1       1000.0   1000.0      0.0       Ptransmission, x, StrengthImmunity, Immunity,
#    222         1       1000.0   1000.0      0.0       StrengthCrossImmunity, prevalence_in_migrants, CCC,
#    223         2    1090000.0 545000.0      0.0       time, Ntimesteps, dt_years) = parameters(params)
#    224
#    225         1       2000.0   2000.0      0.0      Nagents   = int(Nagents)
#    226         1       1000.0   1000.0      0.0      Nstrains  = int(Nstrains)
#    227         1       1000.0   1000.0      0.0      Nst       = int(Nst)
#    228         1       1000.0   1000.0      0.0      AgeDeath  = float(AgeDeath)
#    229         1       1000.0   1000.0      0.0      CCC       = float(CCC)
#    230
#    231                                               # Optionally override Ptransmission
#    232         1       1000.0   1000.0      0.0      if specifyPtransmission == 1:
#    233                                                   Ptransmission = 0.0301
#    234
#    235                                               # ---- Cross-immunity-accelerated recovery probability per step ----
#    236         1       1000.0   1000.0      0.0      dt_weeks = 1.0/7.0  # from parameters.m
#    237         1       7000.0   7000.0      0.0      Rrecovery = -np.log(1.0 - Precovery) / dt_weeks
#    238         1       1000.0   1000.0      0.0      if StrengthCrossImmunity != 1:
#    239         1       2000.0   2000.0      0.0          Rrecovery_cici = 1.0 / ((1.0 / Rrecovery) * (1.0 - StrengthCrossImmunity))
#    240         1       4000.0   4000.0      0.0          Precovery_cici = 1.0 - np.exp(-dt_weeks * Rrecovery_cici)
#    241                                               else:
#    242                                                   Precovery_cici = 1.0
#    243
#    244                                               # ---- Pre-generated random streams (mirrors pregenerate_random_numbers.m) ----
#    245         1   56337000.0 5.63e+07      0.0      ContactRand = np.random.poisson(Cpertimestep, size=(1_000_000, 1)).astype(int)
#    246         1   21149000.0 2.11e+07      0.0      MRRand      = np.random.poisson(MRpertimestep, size=(1_000_000, 1)).astype(int)
#    247         1    3097000.0  3.1e+06      0.0      SamplingU   = np.random.rand(1_000_000, 1)
#    248         1          0.0      0.0      0.0      countCR = 0  # contacts
#    249         1       1000.0   1000.0      0.0      countMR = 0  # migrants
#    250         1          0.0      0.0      0.0      countU  = 0  # generic uniforms
#    251
#    252         1       2000.0   2000.0      0.0      def _takeU(n):
#    253                                                   nonlocal SamplingU, countU
#    254                                                   end = countU + n
#    255                                                   if end > len(SamplingU):
#    256                                                       SamplingU = np.random.rand(1_000_000, 1)
#    257                                                       countU = 0
#    258                                                       end = n
#    259                                                   out = SamplingU[countU:end, 0]
#    260                                                   countU = end
#    261                                                   return out
#    262
#    263         1       1000.0   1000.0      0.0      def _takeCR():
#    264                                                   nonlocal ContactRand, countCR
#    265                                                   x = ContactRand[countCR, 0]
#    266                                                   countCR += 1
#    267                                                   if countCR >= len(ContactRand):
#    268                                                       ContactRand = np.random.poisson(Cpertimestep, size=(1_000_000, 1)).astype(int)
#    269                                                       countCR = 0
#    270                                                   return x
#    271
#    272         1          0.0      0.0      0.0      def _takeMR():
#    273                                                   nonlocal MRRand, countMR
#    274                                                   x = MRRand[countMR, 0]
#    275                                                   countMR += 1
#    276                                                   if countMR >= len(MRRand):
#    277                                                       MRRand = np.random.poisson(MRpertimestep, size=(1_000_000, 1)).astype(int)
#    278                                                       countMR = 0
#    279                                                   return x
#    280
#    281                                               # ---- Outputs ----
#    282         1     170000.0 170000.0      0.0      SSPrev = np.zeros((Nstrains, Ntimesteps), dtype=float)
#    283         1     173000.0 173000.0      0.0      AgentsInfectedByKStrains = np.zeros((Nstrains, Ntimesteps), dtype=float)
#    284
#    285                                               # t = 0
#    286         1       5000.0   5000.0      0.0      BB = AgentCharacteristics[:, :Nstrains]
#    287         1      89000.0  89000.0      0.0      SSPrev[:, 0] = BB.sum(axis=0)
#    288
#    289         1      40000.0  40000.0      0.0      tot0 = BB.sum()
#    290         1       1000.0   1000.0      0.0      if tot0 > 1:
#    291         1      38000.0  38000.0      0.0          kvec = BB.sum(axis=1).astype(int)
#    292         1      25000.0  25000.0      0.0          kvec = kvec[kvec != 0]
#    293         1       1000.0   1000.0      0.0          if kvec.size:
#    294         1      84000.0  84000.0      0.0              K, counts = np.unique(kvec, return_counts=True)
#    295         1       8000.0   8000.0      0.0              AgentsInfectedByKStrains[K - 1, 0] = counts
#    296                                               elif tot0 == 1:
#    297                                                   AgentsInfectedByKStrains[0, 0] = 1
#    298
#    299                                               # Tracks “fast recovery” flags (CICI) for each (agent, strain)
#    300         1      80000.0  80000.0      0.0      CICI = np.zeros_like(BB)
#    301
#    302                                               # ---- Main time loop ----
#    303      7300    1721000.0    235.8      0.0      for t in range(Ntimesteps - 1):
#    304      7299  126173000.0  17286.3      0.0          CurrentAC  = AgentCharacteristics.copy()
#    305      7299  134525000.0  18430.6      0.0          CurrentImm = ImmuneStatus.copy()
#    306      7299   35103000.0   4809.3      0.0          DD = CurrentAC[:, :Nst]  # infections per strain at start of step
#    307
#    308                                                   # ===== RECOVERY =====
#    309      7299  758307000.0 103891.9      0.2          inf_norm = (DD > 0) & (CICI == 0)
#    310      7299  675573000.0  92556.9      0.2          inf_cici = (DD > 0) & (CICI > 0)
#    311
#    312      7299 1613709000.0 221086.3      0.5          r_n_rows, r_n_cols = np.where(inf_norm)
#    313      7299    1795000.0    245.9      0.0          if r_n_rows.size:
#    314      7299   36068000.0   4941.5      0.0              rec = (np.random.rand(r_n_rows.size) < Precovery)
#    315      7299   27608000.0   3782.4      0.0              AgentCharacteristics[r_n_rows[rec], r_n_cols[rec]] = 0
#    316                                                       # only normal recoveries gain ss-immunity
#    317      7299   18236000.0   2498.4      0.0              ImmuneStatus[r_n_rows[rec], r_n_cols[rec]] = 1 * Immunity
#    318
#    319      7299 1587363000.0 217476.8      0.5          r_c_rows, r_c_cols = np.where(inf_cici)
#    320      7299    1823000.0    249.8      0.0          if r_c_rows.size:
#    321      7298   21961000.0   3009.2      0.0              rec = (np.random.rand(r_c_rows.size) < Precovery_cici)
#    322      7298   18973000.0   2599.8      0.0              AgentCharacteristics[r_c_rows[rec], r_c_cols[rec]] = 0
#    323      7298   12913000.0   1769.4      0.0              CICI[r_c_rows[rec], r_c_cols[rec]] = 0  # no immunity granted here
#    324
#    325                                                   # ===== WANING IMMUNITY =====
#    326      7299 2187322000.0 299674.2      0.7          w_rows, w_cols = np.where(CurrentImm == 1)
#    327      7299    1766000.0    242.0      0.0          if w_rows.size:
#    328      7299  230161000.0  31533.2      0.1              lose = (np.random.rand(w_rows.size) < Pimmunityloss)
#    329      7299   46209000.0   6330.9      0.0              ImmuneStatus[w_rows[lose], w_cols[lose]] = 0
#    330
#    331                                                   # ===== TRANSMISSION =====
#    332      7299  241060000.0  33026.4      0.1          G = DD.sum(axis=1)
#    333      7299   33926000.0   4648.0      0.0          infected_agents = np.where(G > 0)[0]
#    334      7299    1721000.0    235.8      0.0          if infected_agents.size:
#    335                                                       # base per-contact susceptibility, with co-infection resistance
#    336      7299  235478000.0  32261.7      0.1              TotalInf = DD.sum(axis=1)
#    337      7299  152034000.0  20829.4      0.0              P1 = Ptransmission * np.power((1.0 - TotalInf / CCC), x)
#    338      7299  111892000.0  15329.8      0.0              P1 = np.clip(P1, 0.0, 1.0)
#    339      7299 1529125000.0 209497.9      0.5              P1 = np.repeat(P1[:, None], Nstrains, axis=1)
#    340      7299  146392000.0  20056.4      0.0              InfectionProb = P1.copy()
#    341
#    342                                                       # strain-specific immunity
#    343      7299    2037000.0    279.1      0.0              if StrengthImmunity > 0:
#    344      7299  113169000.0  15504.7      0.0                  mask_ss = (CurrentImm == 1)
#    345      7299 2340092000.0 320604.5      0.7                  InfectionProb[mask_ss] = P1[mask_ss] * (1.0 - StrengthImmunity)
#    346
#    347                                                       # cross-strain immunity (any immunity to any strain)
#    348      7299    1769000.0    242.4      0.0              if StrengthCrossImmunity > 0:
#    349      7299  209628000.0  28720.1      0.1                  any_imm = (CurrentImm == 1).any(axis=1)[:, None]
#    350      7299 1433750000.0 196431.0      0.5                  mask_cs = (CurrentImm == 0) & np.repeat(any_imm, Nstrains, axis=1)
#    351      7299 2517666000.0 344933.0      0.8                  InfectionProb[mask_cs] = P1[mask_cs] * (1.0 - StrengthCrossImmunity)
#    352
#    353   8796298 2110790000.0    240.0      0.7              for a in infected_agents:
#    354   8788999     2.19e+10   2493.8      6.9                  infecting_strains = np.where(DD[a, :] > 0)[0]
#    355   8788999 7952507000.0    904.8      2.5                  X = _takeCR()  # contacts for this source agent
#    356   8788999 1908374000.0    217.1      0.6                  if X <= 0:
#    357     63274   11815000.0    186.7      0.0                      continue
#    358
#    359                                                           # sample contacts (with replacement), avoid self
#    360   8725725 8762824000.0   1004.3      2.8                  U = _takeU(X)
#    361   8725725     1.68e+10   1930.8      5.3                  contacts = np.ceil(Nagents * U).astype(int) - 1
#    362   8725725 6278590000.0    719.5      2.0                  selfmask = (contacts == a)
#    363   8725725     3.46e+10   3961.3     10.9                  if np.any(selfmask):
#    364     17439   26979000.0   1547.0      0.0                      others = np.arange(Nagents)
#    365     17439   51780000.0   2969.2      0.0                      others = others[others != a]
#    366     17439  289571000.0  16604.8      0.1                      contacts[selfmask] = np.random.choice(others, size=selfmask.sum(), replace=True)
#    367
#    368                                                           # choose one transmitting strain per contact among agent's current strains
#    369   8725725 9286122000.0   1064.2      2.9                  U2 = _takeU(X)
#    370   8725725 1989478000.0    228.0      0.6                  if infecting_strains.size == 1:
#    371   6779375     1.83e+10   2700.4      5.8                      chosen = np.full(X, infecting_strains[0], dtype=int)
#    372                                                           else:
#    373   1946350 3800731000.0   1952.7      1.2                      idx = np.ceil(infecting_strains.size * U2).astype(int) - 1
#    374   1946350  672845000.0    345.7      0.2                      chosen = infecting_strains[idx]
#    375
#    376                                                           # success Bernoulli
#    377   8725725 7908705000.0    906.4      2.5                  susc = InfectionProb[contacts, chosen]
#    378   8725725 9241867000.0   1059.2      2.9                  U3 = _takeU(X)
#    379   8725725 4619148000.0    529.4      1.5                  success = (U3 < susc)
#    380
#    381   8725725      3.4e+10   3891.0     10.7                  if np.any(success):
#    382    769813  438003000.0    569.0      0.1                      contacts = contacts[success]
#    383    769813  361560000.0    469.7      0.1                      chosen   = chosen[success]
#    384                                                               # dedupe same contact (keep first)
#    385    769813 1854038000.0   2408.4      0.6                      order = np.argsort(contacts)
#    386    769813  262696000.0    341.2      0.1                      contacts = contacts[order]
#    387    769813  233680000.0    303.6      0.1                      chosen   = chosen[order]
#    388    769813 6224969000.0   8086.3      2.0                      keep = np.concatenate([[True], np.diff(contacts) > 0])
#    389    769813  389696000.0    506.2      0.1                      contacts = contacts[keep]
#    390    769813  321552000.0    417.7      0.1                      chosen   = chosen[keep]
#    391
#    392                                                               # increment copies from the snapshot state
#    393    769813 1755322000.0   2280.2      0.6                      AgentCharacteristics[contacts, chosen] = CurrentAC[contacts, chosen] + 1
#    394
#    395    769813  203557000.0    264.4      0.1                      if cross_immunity_effect_on_coinfections == 1:
#    396    769813     1.71e+10  22227.3      5.4                          temp = AgentCharacteristics[:, :Nstrains].copy()
#    397    769813  708755000.0    920.7      0.2                          temp[contacts, chosen] = 0               # remove the newly acquired strains
#    398    769813  779291000.0   1012.3      0.2                          temp = temp[contacts, :]
#    399    769813 1042380000.0   1354.1      0.3                          temp[temp > 0] = 1                       # mark other extant strains
#    400    769813     1.01e+10  13085.5      3.2                          add = np.zeros_like(CICI)
#    401    769813  738922000.0    959.9      0.2                          add[contacts, :] = temp
#    402    769813     6.42e+10  83435.3     20.3                          CICI = np.clip(CICI + add, 0, 1)
#    403
#    404                                                               # those contacts cannot be infected again in this pass
#    405    769813  904708000.0   1175.2      0.3                      InfectionProb[contacts, :] = 0.0
#    406
#    407                                                   # ===== AGE, DEATH, BIRTH =====
#    408      7299   59538000.0   8157.0      0.0          AgentCharacteristics[:, Nstrains] = dt_years + CurrentAC[:, Nstrains]
#    409      7299   33242000.0   4554.3      0.0          dead = np.where(AgentCharacteristics[:, Nstrains] > AgeDeath)[0]
#    410      7299    2121000.0    290.6      0.0          if dead.size:
#    411       673     882000.0   1310.5      0.0              AgentCharacteristics[dead, :Nstrains] = 0
#    412       673     739000.0   1098.1      0.0              ImmuneStatus[dead, :] = 0
#    413       673     846000.0   1257.1      0.0              AgentCharacteristics[dead, Nstrains] = 0.001
#    414       673     648000.0    962.9      0.0              CICI[dead, :] = 0
#    415
#    416                                                   # ===== MIGRATION =====
#    417      7299    7556000.0   1035.2      0.0          NumMig = _takeMR()
#    418      7299    2155000.0    295.2      0.0          if NumMig > 0:
#    419      2530     791000.0    312.6      0.0              if NumMig >= Nagents:
#    420                                                           migrants = np.random.permutation(Nagents)
#    421                                                       else:
#    422      2530   79745000.0  31519.8      0.0                  migrants = np.random.choice(Nagents, size=NumMig, replace=False)
#    423
#    424      2530    5680000.0   2245.1      0.0              infected_mig = (np.random.rand(NumMig) < prevalence_in_migrants)
#    425      2530    5485000.0   2168.0      0.0              n_im = int(infected_mig.sum())
#    426      2530     760000.0    300.4      0.0              if n_im > 0:
#    427       310    2626000.0   8471.0      0.0                  mig_strains = np.random.randint(0, Nst, size=n_im)  # 0..Nst-1
#    428
#    429      2530     806000.0    318.6      0.0              cm = ci = 0
#    430      5620    2203000.0    392.0      0.0              for m in range(NumMig):
#    431      3090    1190000.0    385.1      0.0                  idx = migrants[m]
#    432      3090    2184000.0    706.8      0.0                  ImmuneStatus[idx, :] = 0
#    433      3090    1724000.0    557.9      0.0                  CICI[idx, :] = 0
#    434      3090    2915000.0    943.4      0.0                  AgentCharacteristics[idx, Nstrains] = np.random.rand() * AgeDeath
#    435      3090    1707000.0    552.4      0.0                  AgentCharacteristics[idx, :Nstrains] = 0
#    436      3090     952000.0    308.1      0.0                  if infected_mig[cm]:
#    437       315     148000.0    469.8      0.0                      AgentCharacteristics[idx, mig_strains[ci]] = 1
#    438       315      92000.0    292.1      0.0                      ci += 1
#    439      3090     984000.0    318.4      0.0                  cm += 1
#    440
#    441                                                   # ===== RECORDING =====
#    442      7299    3386000.0    463.9      0.0          BB = AgentCharacteristics[:, :Nstrains]
#    443      7299  295002000.0  40416.8      0.1          SSPrev[:, t + 1] = BB.sum(axis=0)
#    444
#    445      7299  254986000.0  34934.4      0.1          tot = BB.sum()
#    446      7299    2924000.0    400.6      0.0          if tot > 1:
#    447      7299  245449000.0  33627.8      0.1              kvec = BB.sum(axis=1).astype(int)
#    448      7299   86863000.0  11900.7      0.0              kvec = kvec[kvec != 0]
#    449      7299    2307000.0    316.1      0.0              if kvec.size:
#    450      7299  204733000.0  28049.5      0.1                  K, counts = np.unique(kvec, return_counts=True)
#    451      7299   15417000.0   2112.2      0.0                  AgentsInfectedByKStrains[K - 1, t + 1] = counts
#    452                                                   elif tot == 1:
#    453                                                       AgentsInfectedByKStrains[0, t + 1] = 1
#    454
#    455         1          0.0      0.0      0.0      return SSPrev, AgentsInfectedByKStrains

# %%
ttime = np.linspace(0.0, DurationSimulation, SSPrev.shape[1])

end = time.perf_counter()
print(f"Elapsed: {end - start:.4f} s")

plt.figure()
plt.xlabel("Time (years)")
plt.ylabel("Number of infections")

# MATLAB line(ttime, SSPrev) plots one line per row (strain),
# so transpose for matplotlib (each column vs x).
plt.plot(ttime, SSPrev.T, linewidth=2)

# Optional axis limits (uncomment to mimic your commented line)
# plt.axis([DurationSimulation - 2, DurationSimulation, 0, 500])

plt.grid(True)
plt.title("Strain-specific infections over time")
plt.show()
